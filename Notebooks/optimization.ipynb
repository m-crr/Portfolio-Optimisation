# %%
# To import .py scripts as modules

import sys

sys.path.append("/Users/rohith_medam/Projects/Portfolio_Optimization/Scripts")
import userdf_fncs
# import plots_fncs

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.subplots as make_subplots
import statsmodels.api as sm
import yfinance as yf
from sklearn.linear_model import LinearRegression

# %%
from scipy.optimize import minimize
import cvxpy as cp
from pypfopt import EfficientFrontier, risk_models, expected_returns
from pypfopt import plotting as pypfopt_plotting

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
plt.style.use("seaborn-v0_8-darkgrid")
sns.set_palette("husl")

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_rows", 100)

# %%
prices_datafile_path = (
    r"/Users/rohith_medam/Projects/Portfolio_Optimization/Data/prices.csv"
)

returns_datafile_path = (
    r"/Users/rohith_medam/Projects/Portfolio_Optimization/Data/returns.csv"
)

volume_datafile_path = (
    r"/Users/rohith_medam/Projects/Portfolio_Optimization/Data/volume.csv"
)

# %%
returns = pd.read_csv(returns_datafile_path, index_col=0, parse_dates=True)

prices = pd.read_csv(prices_datafile_path, index_col=0, parse_dates=True)

volume = pd.read_csv(volume_datafile_path, index_col=0, parse_dates=True)

# %%
beta_capm_df = userdf_fncs.calc_capm(
    returns, market_ticker="^GSPC", lookback_window=10, current_risk_free_rate=0.04259
)

# %%
userdf_fncs.data_write_excel(
    worksheet_names=["CAPM_Returns"],
    dataframes=[beta_capm_df],
    folder_name="Data",
    file_name="data_excel.xlsx",
    date_format="YYYY-MM-DD",
)
